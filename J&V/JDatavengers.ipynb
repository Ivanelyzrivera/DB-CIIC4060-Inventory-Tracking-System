# %%
# import requests
# import pandas as pd

# api = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/warehouses"
# response = requests.get(api)

# warehouses = response.json()

# # print(warehouses)

# df = pd.DataFrame(warehouses)
# df
# Out:
#      W_Address         W_City  W_ID       W_Name
# 0    5 Main ST      Humacao\r     1   Auto Parts
# 1    6 Main ST  Las Piedras\r     2    Auto Zone
# 2    7 Main ST       Caguas\r     3      Pepboys
# 3    8 Main ST     Mayaguez\r     4      Walmart
# 4    9 Main ST        Cidra\r     5    Walgreens
# 5   10 Main ST        Cayey\r     6     Mechanic
# 6   11 Main ST      Isabela\r     7   Los Rivero
# 7   12 Main ST     Guaynabo\r     8  Luis Air Co
# 8   13 Main ST       Dorado\r     9    Pueblo Co
# 9   14 Main ST         Moca\r    10   Basking Co
# 10  15 Main ST         Moca\r    11   Basking Co
# 11  16 Main ST           Moca    12   Basking Co
# 12      madasd            LOL    13       MISAEL
# 13      madasd            LOL    14       MISAEL
# 14      madasd            LOL    15       MISAEL
# 15      madasd            LOL    16       MISAEL
# 16      madasd            LOL    17       MISAEL
# 17      madasd            LOL    19       MISAEL
# 18      madasd            LOL    20       MISAEL
# 19      madasd            LOL    21       MISAEL
# 20      madasd            LOL    22       MISAEL
# 21      madasd            LOL    23       MISAEL
# 22      madasd      aasdjjdas    24       MISAEL
# 23      madasd      aasdjjdas    26       MISAEL
# 24      madasd      aasdjjdas    25         Madd
# 25      madasd      aasdjjdas    27       MISAEL
# 26   Aguadilla         anasco    28  Stefani Inc
# 27   Aguadilla         anasco    29  Stefani Inc
# 28   Aguadilla         anasco    31  Stefani Inc
# 29   Aguadilla         anasco    32  Stefani Inc
# 30   Aguadilla         anasco    33  Stefani Inc
# 31   Aguadilla         anasco    34  Stefani Inc
# 32   Aguadilla         anasco    35  Stefani Inc

# %%
# # Parts by Supplier
# import requests
# import pandas as pd

# gstat_url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
# gstat = "parts/supplier/"
# numbers = [59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72]

# for n in numbers:
#   try:
#         response = requests.get(gstat_url+gstat+str(n))
#         res = response.json()
#         df = pd.DataFrame(res)
#         print(gstat+str(n))
#         display(df)
#   except Exception as e:
#         print(gstat+str(n))
#         print("ERROR: Supplier does not exist or does not currently supply parts.\n")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\nanda\OneDrive - University of Puerto Rico\Desktop\DBP\J&V\.venv\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\nanda\OneDrive - University of Puerto Rico\Desktop\DBP\J&V\JDatavengers.ipynb Cell 2 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/nanda/OneDrive%20-%20University%20of%20Puerto%20Rico/Desktop/DBP/J%26V/JDatavengers.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
#       <a href='vscode-notebook-cell:/c%3A/Users/nanda/OneDrive%20-%20University%20of%20Puerto%20Rico/Desktop/DBP/J%26V/JDatavengers.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> response = requests.post(url+"warehouse/1/profit")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nanda/OneDrive%20-%20University%20of%20Puerto%20Rico/Desktop/DBP/J%26V/JDatavengers.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> warehouses = response.json()
#       <a href='vscode-notebook-cell:/c%3A/Users/nanda/OneDrive%20-%20University%20of%20Puerto%20Rico/Desktop/DBP/J%26V/JDatavengers.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> df = pd.DataFrame(warehouses)
#       <a href='vscode-notebook-cell:/c%3A/Users/nanda/OneDrive%20-%20University%20of%20Puerto%20Rico/Desktop/DBP/J%26V/JDatavengers.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> df
#
# File c:\Users\nanda\OneDrive - University of Puerto Rico\Desktop\DBP\J&V\.venv\Lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# # Local Statistic: Profit by Year
# import requests
# import pandas as pd
# import matplotlib.pyplot as plt
# from IPython.display import display
# import ipywidgets as widgets

# url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
# userVal = {"user_id" : 10}
# response = requests.post(url+"warehouse/1/profit", json = userVal)
# warehouses = response.json()

# #df = pd.DataFrame(warehouses)
# #df

# warehouses = {
#     "profit": [-15226, 0, 0, -6160, 0, 0, 0, 0, 0, 0, 0, 713],
#     "profit_year": [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 3001]
# }

# df = pd.DataFrame(warehouses)

# # Create a simple plot
# plt.figure(figsize=(10, 5))
# plt.bar(df['profit_year'].astype(str), df['profit'], color='skyblue')
# plt.xlabel('Year')
# plt.ylabel('Profit')
# plt.title('Profit by Year')
# plt.xticks(rotation=45)
# plt.tight_layout()  # Adjusts plot to ensure everything fits without overlapping
# plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# # Local Statistic: Top 5 Most Expensive Racks
# import requests
# import pandas as pd

# url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
# userVal = {"user_id" : 10}
# response = requests.post(url+"warehouse/1/rack/expensive", json = userVal)
# warehouses = response.json()

# df = pd.DataFrame(warehouses)
# df
# Out:
#    RackID  TotalProfit
# 0       4         9471
# 1      72         7700
# 2       5         2420
# 3       8         1848
# 4       7          396

# %%
# # Local Statistic: Bottom 3 Part's Type/Material in the Warehouse
# import requests
# import pandas as pd

# url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
# userVal = {"user_id" : 10}
# response = requests.post(url+"warehouse/1/rack/material", json = userVal)
# warehouses = response.json()

# df = pd.DataFrame(warehouses)
# df
# Out:
#    P_Color  P_ID P_Manufacturer    P_Name  P_Price P_Type  P_Weight  S_ID
# 0     azul    48       alemania  tornillo       88  acero        66     2
# 1   blanco    56       alemania  cilindro       66  acero        66    10
# 2  violeta    52         espana    espada       22  acero        66     6

# %%
# # Local Statistic: Top 5 racks with quantity under the 25% capacity threshold
# import requests
# import pandas as pd

# url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
# userVal = {"user_id" : 10}
# response = requests.post(url+"warehouse/1/rack/lowstock", json = userVal)
# warehouses = response.json()

# df = pd.DataFrame(warehouses)
# df
# Out:
#    Capacity  PartID  RackID  Stock  WarehouseID
# 0       100      57       8     24            1
# 1       100      56       7      6            1
# 2       100      54       6      2            1

# %%
# # Local Statistic: Top 3 Suppliers Per Warehouse
# import requests
# import pandas as pd

# url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
# userVal = {"user_id" : 10}
# response = requests.post(url+"warehouse/1/transaction/suppliers", json = userVal)
# warehouses = response.json()

# df = pd.DataFrame(warehouses)
# df
# Out:
#      S_Name  Supplier_ID  W_ID
# 0  de jesus           59     4
# 1      cruz           65     1

# %%
# # Local Statistic: Top 3 Users With Most Exchanges
# import requests
# import pandas as pd

# url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
# userVal = {"user_id" : 10}
# response = requests.post(url+"warehouse/1/users/receivesmost", json = userVal)
# warehouses = response.json()

# df = pd.DataFrame(warehouses)
# df
# Out:
#    ExchangeCount  userID
# 0              6      36
# 1              1       4
# 2              1      35

# %%
# # Local Statistic: Get Top 3 Days smallest Incoming
# import requests
# import pandas as pd

# url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
# userVal = {"user_id" : 10}
# response = requests.post(url+"warehouse/1//transaction/leastcost", json = userVal)
# warehouses = response.json()

# df = pd.DataFrame(warehouses)
# df
# Out:
#   T_Date  T_Year  Total_Daily_Cost
# 0     22    2001             50974

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import requests
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets

# Define functions for each option
def show_profit():
    print("Showing profit...")

    url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    userVal = {"user_id" : 10}
    response = requests.post(url+"warehouse/1/profit", json = userVal)
    warehouses = response.json()

    warehouses = {
        "profit": [-15226, 0, 0, -6160, 0, 0, 0, 0, 0, 0, 0, 713],
        "profit_year": [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 3001]
    }

    df = pd.DataFrame(warehouses)

    plt.figure(figsize=(10, 5))
    plt.bar(df['profit_year'].astype(str), df['profit'], color='skyblue')
    plt.xlabel('Year')
    plt.ylabel('Profit')
    plt.title('Profit by Year')
    plt.xticks(rotation=45)
    plt.tight_layout()  # Adjusts plot to ensure everything fits without overlapping
    plt.show()

def show_top_expensive_racks():
    print("Showing top 5 expensive racks...")
    url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    userVal = {"user_id" : 10}
    response = requests.post(url+"warehouse/1/rack/expensive", json = userVal)
    warehouses = response.json()

    df = pd.DataFrame(warehouses)
    print(df)

def show_bottom_parts_type():
    print("Showing bottom 3 parts type/material...")
    url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    userVal = {"user_id" : 10}
    response = requests.post(url+"warehouse/1/rack/material", json = userVal)
    warehouses = response.json()

    df = pd.DataFrame(warehouses)
    print(df)

def show_racks_under_capacity():
    print("Showing top 5 racks under 25% capacity...")
    url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    userVal = {"user_id" : 10}
    response = requests.post(url+"warehouse/1/rack/lowstock", json = userVal)
    warehouses = response.json()

    df = pd.DataFrame(warehouses)
    print(df)

# Global Statistics Prints 
def show_top_warehouses_racks():
    print("Showing top 10 warehouses with the most racks...")
    gstat_url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    gstat_route = ["most/rack"]
    
    for gstat in gstat_route:
        response = requests.get(gstat_url+gstat)
        res = response.json()
        df = pd.DataFrame(res)
        print(gstat)
        display(df)


def show_top_warehouses_incoming_transactions():
    print("Showing top 5 warehouse that has the most incoming transactions...")
    gstat_url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    gstat_route = ["most/incoming"]
    
    for gstat in gstat_route:
        response = requests.get(gstat_url+gstat)
        res = response.json()
        df = pd.DataFrame(res)
        print(gstat)
        display(df)

def show_top_warehouses_delivers_exchanges(): #aquii
    print("Showing top 5 warehouse that delivers the most exchanges...")
    gstat_url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    gstat_route = ["most/deliver"]
    
    for gstat in gstat_route:
        response = requests.get(gstat_url+gstat)
        res = response.json()
        df = pd.DataFrame(res)
        print(gstat)
        display(df)
        
def show_top_users_transactions():
    print("Showing top 3 users that made the most transactions...")
    gstat_url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    gstat_route = ["most/transactions"]
    
    for gstat in gstat_route:
        response = requests.get(gstat_url+gstat)
        res = response.json()
        df = pd.DataFrame(res)
        print(gstat)
        display(df)

def show_top_warehouses_least_outgoing_transactions(): #aquiiii
    print("Showing top 3 warehouses with the least outgoing transactions...")
    gstat_url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    gstat_route = ["least/outgoing"]
    
    for gstat in gstat_route:
        response = requests.get(gstat_url+gstat)
        res = response.json()
        df = pd.DataFrame(res)
        print(gstat)
        display(df)
    
def show_top_warehouses_cities():
    print("Showing top 3 warehouses cities with the most transactions...")
    gstat_url = "https://datavenge-35c4e96eb954.herokuapp.com/datavengers/"
    gstat_route = ["most/city"]
    
    for gstat in gstat_route:
        response = requests.get(gstat_url+gstat)
        res = response.json()
        df = pd.DataFrame(res)
        print(gstat)
        display(df)
    
# Latest to Oldest Prints         
def show_latest_to_oldest():
    print("Showing latest to oldest transactions...")

def show_oldest_to_latest():
    print("Showing oldest to latest transactions...")

def show_part_prices():
    print("Showing part prices...")

def show_parts_supplied_by_suppliers():
    print("Showing parts supplied by suppliers...")

# Create the dropdowns
local_stats_dropdown = widgets.Dropdown(
    options=['Profit', 'Top 5 Expensive Racks', 'Bottom 3 Parts Type/Material', 'Top 5 Racks Under 25% Capacity', 'Top 3 Suppliers per Warehouse', ''],
    description='Local Stats:',
)

global_stats_dropdown = widgets.Dropdown(
    options=['Top 10 warehouses with the most racks', 'Top 5 warehouses with the most incoming transactions', 'Top 5 warehouses that delivers the most exchanges','Top 3 users that made the most transaction','Top 3 warehouses with the least outgoing transactions', 'Top 3 warehouses cities with the most transactions'],
    description='Global Stats:',
)

transactions_dropdown = widgets.Dropdown(
    options=['Latest to Oldest', 'Oldest to Latest'],
    description='Transactions:',
)

parts_dropdown = widgets.Dropdown(
    options=['Part Prices', 'Parts Supplied by Suppliers'],
    description='Parts:',
)

# Create an output widget to display results
output = widgets.Output()

def on_local_stats_change(change):
    with output:
        clear_output(wait=True)
        if change['type'] == 'change' and change['name'] == 'value':
            if change['new'] == 'Profit':
                show_profit()
            elif change['new'] == 'Top 5 Expensive Racks':
                show_top_expensive_racks()
            elif change['new'] == 'Bottom 3 Parts Type/Material':
                show_bottom_parts_type()
            elif change['new'] == 'Top 5 Racks Under 25% Capacity':
                show_racks_under_capacity()

def on_global_stats_change(change):
    with output:
        clear_output(wait=True)
        if change['type'] == 'change' and change['name'] == 'value':
            if change['new'] == 'Top 10 warehouses with the most racks': #/most/rack
                show_top_warehouses_racks()
            elif change['new'] == 'Top 5 warehouses with the most incoming transactions': #/most/incoming
                show_top_warehouses_incoming_transactions()
            elif change['new'] == 'Top 5 warehouses that delivers the most exchanges': #/most/deliver
                show_top_warehouses_delivers_exchanges()
            elif change['new'] == 'Top 3 users that made the most transactions': #/most/transactions
                show_top_users_transactions()
            elif change['new'] == 'Top 3 warehouses with the least outgoing transactions': #/least/outgoing
                show_top_warehouses_least_outgoing_transactions()
            elif change['new'] == 'Top 3 warehouses cities with the most transactions': #/most/city
                show_top_warehouses_cities()

def on_transactions_change(change):
    with output:
        clear_output(wait=True)
        if change['type'] == 'change' and change['name'] == 'value':
            if change['new'] == 'Latest to Oldest':
                show_latest_to_oldest()
            elif change['new'] == 'Oldest to Latest':
                show_oldest_to_latest()

def on_parts_dropdown_change(change):
    with output:
        clear_output(wait=True)
        if change['type'] == 'change' and change['name'] == 'value':
            if change['new'] == 'Part Prices':
                show_part_prices()
            elif change['new'] == 'Parts Supplied by Suppliers':
                show_parts_supplied_by_suppliers()



# Register the event handlers
local_stats_dropdown.observe(on_local_stats_change, names='value')
global_stats_dropdown.observe(on_global_stats_change, names='value')
transactions_dropdown.observe(on_transactions_change, names='value')
parts_dropdown.observe(on_parts_dropdown_change, names='value')

# Layout the widgets
title_widget = widgets.HTML(
    value="<h2 style='text-align: center;'>Datavengers - Phase 3</h2>"
)
dropdowns_vbox = widgets.HBox([local_stats_dropdown, global_stats_dropdown, transactions_dropdown, parts_dropdown],layout=widgets.Layout(justify_content='center', width='100%'))
main_vbox = widgets.VBox([title_widget, dropdowns_vbox, output])

# Display the main layout
display(main_vbox)
# Out:
# VBox(children=(HTML(value="<h2 style='text-align: center;'>Datavengers - Phase 3</h2>"), HBox(children=(Dropdo…
